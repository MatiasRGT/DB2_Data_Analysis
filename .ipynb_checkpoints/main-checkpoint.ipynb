# %% [markdown]
# # Precios Consumidor Chile 2018 - 2024 Q2
# <h3> datos.gob.cl - Precios al consumidor <br>
#
# ---

# %% [markdown]
# ## Instalar profiling

# %%
pip install ydata_profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 8.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 54.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 48.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 45.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 20.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ---
# ## Cargar CSV

# %%
# Carga CSV
import pandas as pd

df = pd.read_csv('precio_consumidor_2018.csv')
df.head()
# Out:
#     Año  Mes  Semana Fecha inicio Fecha término  ID región  \
# 0  2018    1       1   2018-01-01    2018-01-05          4
# 1  2018    1       1   2018-01-01    2018-01-05          4
# 2  2018    1       1   2018-01-01    2018-01-05          4
# 3  2018    1       1   2018-01-01    2018-01-05          4
# 4  2018    1       1   2018-01-01    2018-01-05          4
#
#                Región    Sector Tipo de punto monitoreo         Grupo  \
# 0  Región de Coquimbo  Coquimbo              Carnicería  Carne bovina
# 1  Región de Coquimbo  Coquimbo              Carnicería  Carne bovina
# 2  Región de Coquimbo  Coquimbo              Carnicería  Carne bovina
# 3  Región de Coquimbo  Coquimbo              Carnicería  Carne bovina
# 4  Región de Coquimbo  Coquimbo              Carnicería  Carne bovina
#
#           Producto Variedad Calidad  Unidad  Precio mínimo  Precio máximo  \
# 0         Abastero      NaN     NaN  $/kilo           5898           6298
# ...

# %% [markdown]
# ---
# ## Usando Profiling

# %%
df_nodo1 = pd.read_csv("precio_consumidor_2018.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_nodo1 = pd.read_json("precio_consumidor_2018.csv")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/json/_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
# ...
